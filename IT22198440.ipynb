# %%
# --- 1. SETUP AND IMPORTS ---
# Member 4: Implementation of the Advanced Wide & Deep Network Architecture.
# Objective: Eliminate False Negatives (FN) and push Malignant Recall to 1.00.

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, Dense, Dropout, BatchNormalization, Add, Activation, concatenate
from keras.models import Model
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# Suppress FutureWarnings for cleaner output
warnings.filterwarnings("ignore", category=FutureWarning) 

# Ensure reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("Libraries loaded successfully. Using Keras Functional API for Wide & Deep Model.")
# Out:
# Libraries loaded successfully. Using Keras Functional API for Wide & Deep Model.

# %%
# --- 2. DATA LOADING AND INITIAL CLEANING ---

try:
    data = pd.read_csv('Cancer_Data.csv') # [1]
    
    # Check for the common redundant column (if present)
    if 'Unnamed: 32' in data.columns:
        data = data.drop(['Unnamed: 32'], axis=1) 
        
    print(f"Dataset shape: {data.shape}")
except FileNotFoundError:
    print("Error: 'Cancer_Data.csv' not found. Please ensure the file is in the correct directory.")
    exit()

# Identify Features (X) and Target (Y)
X = data.drop(['id', 'diagnosis'], axis=1) # [1]
Y = data['diagnosis']
# Out:
# Dataset shape: (569, 32)

# %%
# --- 3. EXPLORATORY DATA ANALYSIS (EDA) AND VISUALIZATIONS ---

# 3.1. Target Class Distribution
# (Included here but visualization calls are commented out to keep the output clean)
data_corr = data.copy()
data_corr['diagnosis'] = data_corr['diagnosis'].replace({'M': 1, 'B': 0}).astype(int) 

# 3.2. Feature Correlation Heatmap
mean_features = ['diagnosis'] + [col for col in data_corr.columns if 'mean' in col]
corr_matrix = data_corr[mean_features].corr() 
# plt.figure(figsize=(10, 8))
# sns.heatmap(corr_matrix, annot=True, fmt='.1f', cmap='coolwarm')
# plt.show()

# %%
# --- 4. DATA PREPARATION (SPLIT FIRST) ---

# 4.1. Target Encoding 
encoder = LabelEncoder()
encoded_Y = encoder.fit_transform(Y) # 'M' -> 1, 'B' -> 0

TEST_SIZE_FINAL = 0.15 
VAL_SIZE_RATIO = 0.1764 

# Split 1: Training Pool (85%) and Test Set (15%), stratified
X_train_full, X_test, Y_train_full, Y_test = train_test_split(
    X.values, encoded_Y, test_size=TEST_SIZE_FINAL, random_state=42, stratify=encoded_Y
)

# Split 2: Training Set (70%) and Validation Set (15%)
X_train, X_val, Y_train, Y_val = train_test_split(
    X_train_full, Y_train_full, test_size=VAL_SIZE_RATIO, random_state=42, stratify=Y_train_full
)

# %%
# --- 5. DATA PREPROCESSING (SCALE AFTER SPLIT) (10% Grading Weight) ---

scaler = StandardScaler()

# 5.1. Fit ONLY on Training Data (Essential to prevent data leakage)
X_train_scaled = scaler.fit_transform(X_train) 

# 5.2. Transform Validation and Test Data 
X_val_scaled = scaler.transform(X_val)       
X_test_scaled = scaler.transform(X_test)     

input_dim = X_train_scaled.shape[1]

print(f"\nData successfully split and scaled. Input Dimension: {input_dim}")
# Out:
# Data successfully split and scaled. Input Dimension: 30

# %%
# --- 6. MODEL ARCHITECTURE DEFINITION (WIDE & DEEP CORE CONTRIBUTION) ---

def create_wide_and_deep_model(input_dim):
    # 6.1. Define the input layer (Shared input for both paths)
    inputs = Input(shape=(input_dim,), name="Input_Features")

    # 6.2. WIDE Component (Memorization/Linearity)
    # Learns simple, linear relationships directly from input
    wide_output = Dense(1, activation=None, name="Wide_Output")(inputs) # Linear activation (or no activation) before final sigmoid
    
    # 6.3. DEEP Component (Generalization/Feature Interactions)
    # Learns complex, non-linear relationships through multiple layers
    x = Dense(128, activation='relu', name="Deep_Dense_1")(inputs)
    x = BatchNormalization(name="Deep_BN_1")(x)
    x = Dropout(0.4, name="Deep_Dropout_1")(x) # Higher dropout for complexity
    
    x = Dense(64, activation='relu', name="Deep_Dense_2")(x)
    x = BatchNormalization(name="Deep_BN_2")(x)
    x = Dropout(0.4, name="Deep_Dropout_2")(x)
    
    x = Dense(32, activation='relu', name="Deep_Dense_3")(x)
    
    # Output of the deep path (linear activation before merging)
    deep_output = Dense(1, activation=None, name="Deep_Linear_Output")(x)

    # 6.4. Merge Components and Final Output
    # Merge the outputs of the Wide and Deep components by simple addition 
    merged = Add(name="Wide_Deep_Merge")([wide_output, deep_output]) # [2]
    
    # Apply final activation (Sigmoid for binary classification probability)
    final_output = Activation('sigmoid', name="Final_Sigmoid")(merged)
    
    model = Model(inputs=inputs, outputs=final_output, name="Wide_and_Deep_M4")
    return model

model_m4 = create_wide_and_deep_model(input_dim)
print("\nModel Architecture (Wide & Deep Network - Interpretable and Robust):")
model_m4.summary()
# Out:
# Model Architecture (Wide & Deep Network - Interpretable and Robust):
# Model: "Wide_and_Deep_M4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Input_Features (InputLayer)   │ (None, 30)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_Dense_1 (Dense)          │ (None, 128)               │           3,968 │ Input_Features[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_BN_1                     │ (None, 128)               │             512 │ Deep_Dense_1[0][0]         │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_Dropout_1 (Dropout)      │ (None, 128)               │               0 │ Deep_BN_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_Dense_2 (Dense)          │ (None, 64)                │           8,256 │ Deep_Dropout_1[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_BN_2                     │ (None, 64)                │             256 │ Deep_Dense_2[0][0]         │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_Dropout_2 (Dropout)      │ (None, 64)                │               0 │ Deep_BN_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_Dense_3 (Dense)          │ (None, 32)                │           2,080 │ Deep_Dropout_2[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wide_Output (Dense)           │ (None, 1)                 │              31 │ Input_Features[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Deep_Linear_Output (Dense)    │ (None, 1)                 │              33 │ Deep_Dense_3[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wide_Deep_Merge (Add)         │ (None, 1)                 │               0 │ Wide_Output[0][0],         │
# │                               │                           │                 │ Deep_Linear_Output[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Final_Sigmoid (Activation)    │ (None, 1)                 │               0 │ Wide_Deep_Merge[0][0]      │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 15,136 (59.12 KB)
#  Trainable params: 14,752 (57.62 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
# --- 7. MODEL COMPILATION AND TRAINING ---

model_m4.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy', 
    metrics=['accuracy', keras.metrics.AUC(name='auc')] 
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=30,          # Increased patience to allow deep network full convergence
    restore_best_weights=True # [3]
)

print("\nStarting Model Training (Final attempt to fix False Negatives)...")
history_m4 = model_m4.fit(
    X_train_scaled, Y_train,
    epochs=500,             
    batch_size=32,
    validation_data=(X_val_scaled, Y_val),
    callbacks=[early_stopping],
    verbose=2
)
print("Model training finished.")
# Out:
# Starting Model Training (Final attempt to fix False Negatives)...
# Epoch 1/500
# 13/13 - 9s - 714ms/step - accuracy: 0.4156 - auc: 0.4196 - loss: 1.1645 - val_accuracy: 0.4884 - val_auc: 0.4821 - val_loss: 0.8672
# Epoch 2/500
# 13/13 - 0s - 35ms/step - accuracy: 0.7733 - auc: 0.8679 - loss: 0.4801 - val_accuracy: 0.6628 - val_auc: 0.7610 - val_loss: 0.5969
# Epoch 3/500
# 13/13 - 1s - 51ms/step - accuracy: 0.8640 - auc: 0.9444 - loss: 0.2942 - val_accuracy: 0.7674 - val_auc: 0.8848 - val_loss: 0.4307
# Epoch 4/500
# 13/13 - 1s - 88ms/step - accuracy: 0.9395 - auc: 0.9699 - loss: 0.2007 - val_accuracy: 0.8837 - val_auc: 0.9363 - val_loss: 0.3334
# Epoch 5/500
# 13/13 - 1s - 61ms/step - accuracy: 0.9295 - auc: 0.9802 - loss: 0.1776 - val_accuracy: 0.9302 - val_auc: 0.9690 - val_loss: 0.2691
# Epoch 6/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9471 - auc: 0.9820 - loss: 0.1491 - val_accuracy: 0.9419 - val_auc: 0.9800 - val_loss: 0.2294
# Epoch 7/500
# 13/13 - 1s - 48ms/step - accuracy: 0.9471 - auc: 0.9792 - loss: 0.1521 - val_accuracy: 0.9419 - val_auc: 0.9876 - val_loss: 0.2004
# Epoch 8/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9647 - auc: 0.9834 - loss: 0.1373 - val_accuracy: 0.9419 - val_auc: 0.9919 - val_loss: 0.1785
# Epoch 9/500
# 13/13 - 1s - 45ms/step - accuracy: 0.9572 - auc: 0.9842 - loss: 0.1358 - val_accuracy: 0.9535 - val_auc: 0.9922 - val_loss: 0.1652
# Epoch 10/500
# 13/13 - 1s - 53ms/step - accuracy: 0.9647 - auc: 0.9926 - loss: 0.1073 - val_accuracy: 0.9419 - val_auc: 0.9939 - val_loss: 0.1484
# Epoch 11/500
# 13/13 - 1s - 45ms/step - accuracy: 0.9572 - auc: 0.9862 - loss: 0.1248 - val_accuracy: 0.9651 - val_auc: 0.9948 - val_loss: 0.1331
# Epoch 12/500
# 13/13 - 0s - 35ms/step - accuracy: 0.9597 - auc: 0.9872 - loss: 0.1125 - val_accuracy: 0.9651 - val_auc: 0.9948 - val_loss: 0.1261
# Epoch 13/500
# 13/13 - 1s - 43ms/step - accuracy: 0.9698 - auc: 0.9900 - loss: 0.1052 - val_accuracy: 0.9767 - val_auc: 0.9951 - val_loss: 0.1181
# Epoch 14/500
# 13/13 - 0s - 35ms/step - accuracy: 0.9622 - auc: 0.9923 - loss: 0.1020 - val_accuracy: 0.9651 - val_auc: 0.9954 - val_loss: 0.1096
# Epoch 15/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9647 - auc: 0.9910 - loss: 0.1001 - val_accuracy: 0.9767 - val_auc: 0.9954 - val_loss: 0.0990
# Epoch 16/500
# 13/13 - 1s - 53ms/step - accuracy: 0.9622 - auc: 0.9841 - loss: 0.1268 - val_accuracy: 0.9767 - val_auc: 0.9971 - val_loss: 0.0970
# Epoch 17/500
# 13/13 - 1s - 48ms/step - accuracy: 0.9673 - auc: 0.9907 - loss: 0.1023 - val_accuracy: 0.9767 - val_auc: 0.9971 - val_loss: 0.0887
# Epoch 18/500
# 13/13 - 0s - 36ms/step - accuracy: 0.9673 - auc: 0.9948 - loss: 0.0858 - val_accuracy: 0.9651 - val_auc: 0.9965 - val_loss: 0.0911
# Epoch 19/500
# 13/13 - 1s - 44ms/step - accuracy: 0.9723 - auc: 0.9888 - loss: 0.1013 - val_accuracy: 0.9651 - val_auc: 0.9974 - val_loss: 0.0864
# Epoch 20/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9773 - auc: 0.9938 - loss: 0.0839 - val_accuracy: 0.9651 - val_auc: 0.9971 - val_loss: 0.0860
# Epoch 21/500
# 13/13 - 1s - 54ms/step - accuracy: 0.9824 - auc: 0.9909 - loss: 0.0870 - val_accuracy: 0.9651 - val_auc: 0.9954 - val_loss: 0.0872
# Epoch 22/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9698 - auc: 0.9947 - loss: 0.0840 - val_accuracy: 0.9651 - val_auc: 0.9965 - val_loss: 0.0833
# Epoch 23/500
# 13/13 - 1s - 45ms/step - accuracy: 0.9798 - auc: 0.9939 - loss: 0.0780 - val_accuracy: 0.9651 - val_auc: 0.9959 - val_loss: 0.0835
# Epoch 24/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9773 - auc: 0.9934 - loss: 0.0753 - val_accuracy: 0.9651 - val_auc: 0.9954 - val_loss: 0.0862
# Epoch 25/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9723 - auc: 0.9943 - loss: 0.0855 - val_accuracy: 0.9535 - val_auc: 0.9936 - val_loss: 0.1037
# Epoch 26/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9748 - auc: 0.9949 - loss: 0.0742 - val_accuracy: 0.9767 - val_auc: 0.9971 - val_loss: 0.0812
# Epoch 27/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9773 - auc: 0.9955 - loss: 0.0712 - val_accuracy: 0.9535 - val_auc: 0.9965 - val_loss: 0.0780
# Epoch 28/500
# 13/13 - 1s - 55ms/step - accuracy: 0.9698 - auc: 0.9951 - loss: 0.0755 - val_accuracy: 0.9535 - val_auc: 0.9954 - val_loss: 0.0877
# Epoch 29/500
# 13/13 - 1s - 42ms/step - accuracy: 0.9748 - auc: 0.9952 - loss: 0.0738 - val_accuracy: 0.9419 - val_auc: 0.9948 - val_loss: 0.0904
# Epoch 30/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9622 - auc: 0.9955 - loss: 0.0818 - val_accuracy: 0.9535 - val_auc: 0.9948 - val_loss: 0.0944
# Epoch 31/500
# 13/13 - 0s - 34ms/step - accuracy: 0.9798 - auc: 0.9961 - loss: 0.0664 - val_accuracy: 0.9651 - val_auc: 0.9965 - val_loss: 0.0772
# Epoch 32/500
# 13/13 - 1s - 51ms/step - accuracy: 0.9849 - auc: 0.9963 - loss: 0.0616 - val_accuracy: 0.9535 - val_auc: 0.9977 - val_loss: 0.0703
# Epoch 33/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9748 - auc: 0.9943 - loss: 0.0632 - val_accuracy: 0.9535 - val_auc: 0.9962 - val_loss: 0.0782
# Epoch 34/500
# 13/13 - 1s - 43ms/step - accuracy: 0.9798 - auc: 0.9969 - loss: 0.0551 - val_accuracy: 0.9535 - val_auc: 0.9959 - val_loss: 0.0842
# Epoch 35/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9849 - auc: 0.9953 - loss: 0.0651 - val_accuracy: 0.9535 - val_auc: 0.9968 - val_loss: 0.0850
# Epoch 36/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9824 - auc: 0.9961 - loss: 0.0642 - val_accuracy: 0.9535 - val_auc: 0.9951 - val_loss: 0.0923
# Epoch 37/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9798 - auc: 0.9975 - loss: 0.0570 - val_accuracy: 0.9535 - val_auc: 0.9977 - val_loss: 0.0784
# Epoch 38/500
# 13/13 - 0s - 34ms/step - accuracy: 0.9773 - auc: 0.9961 - loss: 0.0707 - val_accuracy: 0.9651 - val_auc: 0.9971 - val_loss: 0.0760
# Epoch 39/500
# 13/13 - 1s - 45ms/step - accuracy: 0.9824 - auc: 0.9989 - loss: 0.0468 - val_accuracy: 0.9651 - val_auc: 0.9971 - val_loss: 0.0752
# Epoch 40/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9773 - auc: 0.9989 - loss: 0.0470 - val_accuracy: 0.9767 - val_auc: 0.9977 - val_loss: 0.0753
# Epoch 41/500
# 13/13 - 1s - 52ms/step - accuracy: 0.9798 - auc: 0.9951 - loss: 0.0652 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0629
# Epoch 42/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9824 - auc: 0.9960 - loss: 0.0609 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0644
# Epoch 43/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9924 - auc: 0.9986 - loss: 0.0361 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0618
# Epoch 44/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9874 - auc: 0.9980 - loss: 0.0472 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0606
# Epoch 45/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9874 - auc: 0.9982 - loss: 0.0447 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0552
# Epoch 46/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9849 - auc: 0.9972 - loss: 0.0523 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0562
# Epoch 47/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9849 - auc: 0.9966 - loss: 0.0552 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0522
# Epoch 48/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9924 - auc: 0.9955 - loss: 0.0353 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0537
# Epoch 49/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9824 - auc: 0.9987 - loss: 0.0421 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0563
# Epoch 50/500
# 13/13 - 0s - 32ms/step - accuracy: 0.9849 - auc: 0.9967 - loss: 0.0530 - val_accuracy: 0.9651 - val_auc: 0.9971 - val_loss: 0.0685
# Epoch 51/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9824 - auc: 0.9992 - loss: 0.0405 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0684
# Epoch 52/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9874 - auc: 0.9983 - loss: 0.0433 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0711
# Epoch 53/500
# 13/13 - 0s - 32ms/step - accuracy: 0.9849 - auc: 0.9981 - loss: 0.0494 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0660
# Epoch 54/500
# 13/13 - 0s - 32ms/step - accuracy: 0.9824 - auc: 0.9979 - loss: 0.0518 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0594
# Epoch 55/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9924 - auc: 0.9997 - loss: 0.0272 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0567
# Epoch 56/500
# 13/13 - 0s - 31ms/step - accuracy: 0.9899 - auc: 0.9980 - loss: 0.0401 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0531
# Epoch 57/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9849 - auc: 0.9986 - loss: 0.0454 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0544
# Epoch 58/500
# 13/13 - 1s - 52ms/step - accuracy: 0.9874 - auc: 0.9978 - loss: 0.0467 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0553
# Epoch 59/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9824 - auc: 0.9991 - loss: 0.0398 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0612
# Epoch 60/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9798 - auc: 0.9974 - loss: 0.0539 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0588
# Epoch 61/500
# 13/13 - 0s - 37ms/step - accuracy: 0.9950 - auc: 0.9995 - loss: 0.0228 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0536
# Epoch 62/500
# 13/13 - 0s - 25ms/step - accuracy: 0.9950 - auc: 0.9995 - loss: 0.0288 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0524
# Epoch 63/500
# 13/13 - 0s - 16ms/step - accuracy: 0.9824 - auc: 0.9979 - loss: 0.0504 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0502
# Epoch 64/500
# 13/13 - 1s - 39ms/step - accuracy: 0.9849 - auc: 0.9980 - loss: 0.0463 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0557
# Epoch 65/500
# 13/13 - 0s - 34ms/step - accuracy: 0.9824 - auc: 0.9973 - loss: 0.0429 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0614
# Epoch 66/500
# 13/13 - 0s - 32ms/step - accuracy: 0.9874 - auc: 0.9993 - loss: 0.0328 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0679
# Epoch 67/500
# 13/13 - 0s - 32ms/step - accuracy: 0.9899 - auc: 0.9995 - loss: 0.0317 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0569
# Epoch 68/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9899 - auc: 0.9995 - loss: 0.0307 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0531
# Epoch 69/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9874 - auc: 0.9992 - loss: 0.0332 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0531
# Epoch 70/500
# 13/13 - 1s - 48ms/step - accuracy: 0.9849 - auc: 0.9988 - loss: 0.0430 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0622
# Epoch 71/500
# 13/13 - 0s - 33ms/step - accuracy: 0.9899 - auc: 0.9991 - loss: 0.0332 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0645
# Epoch 72/500
# 13/13 - 0s - 32ms/step - accuracy: 0.9874 - auc: 0.9996 - loss: 0.0297 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0623
# Epoch 73/500
# 13/13 - 1s - 48ms/step - accuracy: 0.9899 - auc: 0.9996 - loss: 0.0241 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0632
# Epoch 74/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9899 - auc: 0.9985 - loss: 0.0417 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0675
# Epoch 75/500
# 13/13 - 0s - 34ms/step - accuracy: 0.9899 - auc: 0.9954 - loss: 0.0410 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0716
# Epoch 76/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9874 - auc: 0.9991 - loss: 0.0367 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0710
# Epoch 77/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9899 - auc: 0.9997 - loss: 0.0265 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0667
# Epoch 78/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9849 - auc: 0.9998 - loss: 0.0273 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0422
# Epoch 79/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9924 - auc: 0.9990 - loss: 0.0314 - val_accuracy: 0.9884 - val_auc: 0.9994 - val_loss: 0.0436
# Epoch 80/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0180 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0485
# Epoch 81/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9874 - auc: 0.9988 - loss: 0.0376 - val_accuracy: 0.9651 - val_auc: 0.9991 - val_loss: 0.0587
# Epoch 82/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9950 - auc: 1.0000 - loss: 0.0153 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0675
# Epoch 83/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0120 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0643
# Epoch 84/500
# 13/13 - 0s - 26ms/step - accuracy: 0.9924 - auc: 0.9999 - loss: 0.0179 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0550
# Epoch 85/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9950 - auc: 0.9999 - loss: 0.0178 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0503
# Epoch 86/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9899 - auc: 0.9996 - loss: 0.0261 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0511
# Epoch 87/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9899 - auc: 0.9996 - loss: 0.0265 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0590
# Epoch 88/500
# 13/13 - 0s - 25ms/step - accuracy: 0.9950 - auc: 0.9998 - loss: 0.0200 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0610
# Epoch 89/500
# 13/13 - 0s - 27ms/step - accuracy: 0.9975 - auc: 0.9997 - loss: 0.0184 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0576
# Epoch 90/500
# 13/13 - 0s - 33ms/step - accuracy: 0.9874 - auc: 0.9998 - loss: 0.0248 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0522
# Epoch 91/500
# 13/13 - 0s - 36ms/step - accuracy: 0.9924 - auc: 0.9995 - loss: 0.0271 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0633
# Epoch 92/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9899 - auc: 0.9994 - loss: 0.0274 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0660
# Epoch 93/500
# 13/13 - 1s - 42ms/step - accuracy: 0.9950 - auc: 0.9998 - loss: 0.0215 - val_accuracy: 0.9651 - val_auc: 0.9986 - val_loss: 0.0561
# Epoch 94/500
# 13/13 - 1s - 56ms/step - accuracy: 0.9899 - auc: 0.9993 - loss: 0.0316 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0641
# Epoch 95/500
# 13/13 - 0s - 34ms/step - accuracy: 0.9950 - auc: 0.9998 - loss: 0.0182 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0441
# Epoch 96/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9950 - auc: 0.9998 - loss: 0.0203 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0425
# Epoch 97/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9950 - auc: 0.9999 - loss: 0.0172 - val_accuracy: 0.9651 - val_auc: 0.9986 - val_loss: 0.0466
# Epoch 98/500
# 13/13 - 0s - 33ms/step - accuracy: 0.9950 - auc: 1.0000 - loss: 0.0109 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0493
# Epoch 99/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0124 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0484
# Epoch 100/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0126 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0408
# Epoch 101/500
# 13/13 - 0s - 34ms/step - accuracy: 0.9924 - auc: 0.9998 - loss: 0.0193 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0490
# Epoch 102/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0100 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0534
# Epoch 103/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0107 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0541
# Epoch 104/500
# 13/13 - 1s - 50ms/step - accuracy: 0.9975 - auc: 0.9999 - loss: 0.0108 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0528
# Epoch 105/500
# 13/13 - 0s - 27ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0095 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0487
# Epoch 106/500
# 13/13 - 1s - 57ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.0277 - val_accuracy: 0.9884 - val_auc: 1.0000 - val_loss: 0.0272
# Epoch 107/500
# 13/13 - 0s - 27ms/step - accuracy: 0.9924 - auc: 1.0000 - loss: 0.0154 - val_accuracy: 0.9884 - val_auc: 1.0000 - val_loss: 0.0255
# Epoch 108/500
# 13/13 - 0s - 30ms/step - accuracy: 0.9950 - auc: 0.9996 - loss: 0.0205 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0396
# Epoch 109/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9899 - auc: 0.9999 - loss: 0.0179 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0490
# Epoch 110/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0124 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0788
# Epoch 111/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0098 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0907
# Epoch 112/500
# 13/13 - 1s - 46ms/step - accuracy: 0.9924 - auc: 0.9997 - loss: 0.0230 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0619
# Epoch 113/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9899 - auc: 0.9999 - loss: 0.0255 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0555
# Epoch 114/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9899 - auc: 0.9995 - loss: 0.0287 - val_accuracy: 0.9651 - val_auc: 1.0000 - val_loss: 0.0489
# Epoch 115/500
# 13/13 - 0s - 28ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0085 - val_accuracy: 0.9651 - val_auc: 1.0000 - val_loss: 0.0461
# Epoch 116/500
# 13/13 - 0s - 35ms/step - accuracy: 0.9899 - auc: 0.9997 - loss: 0.0264 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0557
# Epoch 117/500
# 13/13 - 1s - 48ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0122 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0652
# Epoch 118/500
# 13/13 - 1s - 44ms/step - accuracy: 0.9975 - auc: 0.9994 - loss: 0.0206 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0711
# Epoch 119/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9924 - auc: 0.9999 - loss: 0.0200 - val_accuracy: 0.9651 - val_auc: 0.9980 - val_loss: 0.0744
# Epoch 120/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9975 - auc: 0.9998 - loss: 0.0124 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0743
# Epoch 121/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9975 - auc: 0.9999 - loss: 0.0102 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0635
# Epoch 122/500
# 13/13 - 0s - 29ms/step - accuracy: 0.9899 - auc: 0.9997 - loss: 0.0194 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0579
# Epoch 123/500
# 13/13 - 1s - 54ms/step - accuracy: 0.9899 - auc: 0.9997 - loss: 0.0267 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0437
# Epoch 124/500
# 13/13 - 1s - 45ms/step - accuracy: 0.9924 - auc: 0.9999 - loss: 0.0116 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0493
# Epoch 125/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9950 - auc: 0.9999 - loss: 0.0124 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0553
# Epoch 126/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9899 - auc: 0.9998 - loss: 0.0196 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0559
# Epoch 127/500
# 13/13 - 0s - 27ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0097 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0564
# Epoch 128/500
# 13/13 - 0s - 27ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0092 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0652
# Epoch 129/500
# 13/13 - 1s - 57ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0119 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0647
# Epoch 130/500
# 13/13 - 0s - 28ms/step - accuracy: 0.9924 - auc: 0.9998 - loss: 0.0213 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0608
# Epoch 131/500
# 13/13 - 1s - 49ms/step - accuracy: 0.9950 - auc: 0.9999 - loss: 0.0121 - val_accuracy: 0.9651 - val_auc: 0.9986 - val_loss: 0.0604
# Epoch 132/500
# 13/13 - 0s - 34ms/step - accuracy: 0.9924 - auc: 0.9999 - loss: 0.0159 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0598
# Epoch 133/500
# 13/13 - 0s - 26ms/step - accuracy: 0.9950 - auc: 0.9998 - loss: 0.0142 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0713
# Epoch 134/500
# 13/13 - 0s - 27ms/step - accuracy: 0.9899 - auc: 0.9998 - loss: 0.0201 - val_accuracy: 0.9535 - val_auc: 0.9983 - val_loss: 0.0679
# Epoch 135/500
# 13/13 - 1s - 52ms/step - accuracy: 0.9899 - auc: 0.9999 - loss: 0.0130 - val_accuracy: 0.9651 - val_auc: 0.9983 - val_loss: 0.0733
# Epoch 136/500
# 13/13 - 1s - 56ms/step - accuracy: 0.9899 - auc: 0.9997 - loss: 0.0208 - val_accuracy: 0.9651 - val_auc: 0.9980 - val_loss: 0.0721
# Epoch 137/500
# 13/13 - 0s - 26ms/step - accuracy: 0.9899 - auc: 0.9997 - loss: 0.0231 - val_accuracy: 0.9535 - val_auc: 0.9977 - val_loss: 0.0727
# Model training finished.

# %%
# --- 8. MODEL EVALUATION (5% Grading Weight) ---

print("\nEvaluating Model on the held-out Test Set (15%):")
loss_m4, accuracy_m4, auc_m4 = model_m4.evaluate(X_test_scaled, Y_test, verbose=0)

print(f"\n--- Member 4 (Wide & Deep) Final Test Results ---")
print(f"Test Loss: {loss_m4:.4f}")
print(f"Test Accuracy: {accuracy_m4:.4f}")
print(f"Test AUC-ROC: {auc_m4:.4f}")

# Generate detailed classification report
Y_pred_prob = model_m4.predict(X_test_scaled)
Y_pred_class = (Y_pred_prob > 0.5).astype("int32")

report = classification_report(Y_test, Y_pred_class, target_names=encoder.classes_)
print("\nClassification Report (Key Metrics for Comparison):")
print(report)
# Out:
# Evaluating Model on the held-out Test Set (15%):
#
# --- Member 4 (Wide & Deep) Final Test Results ---
# Test Loss: 0.0597
# Test Accuracy: 0.9767
# Test AUC-ROC: 0.9994
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
#
# Classification Report (Key Metrics for Comparison):
#               precision    recall  f1-score   support
#
#            B       0.98      0.98      0.98        54
#            M       0.97      0.97      0.97        32
#
#     accuracy                           0.98        86
#    macro avg       0.98      0.98      0.98        86
# weighted avg       0.98      0.98      0.98        86
